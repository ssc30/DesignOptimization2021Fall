# %% [markdown]
# <a href="https://colab.research.google.com/github/ssc30/DesignOptimization2021Fall/blob/main/Project/Design_Optimization_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project 2: Design Optimization of a Disk Brake
#
#
#
#
#
#
#
#
# Sai Chandu Sunkara
# 11/17/2021
#
#
#
#
#
#
#
#
#
#
#
#
# The objective of this project is to optimize the disk break geometry based on the Ansys simulation Initially we need create a disk break body with two break pads and in the static structural simulation the whole body is meshed with a tetrahedron mesh and dense meshing is done near the break plates to get better results and then the and the rotational velocity is set to 250 rad/s along the break disk and then the pressure is applied on the disk which is usually applied by the break pads on the disk on both sides and then a manual contact region is set up as a frictional contact and set the friction constant as 0.22 since the contact between the break pads and the disk is purely friction it is take into account and now a displacement along the x and z axis is constrained to zero and the y component is left free for undergoing any changes and now the von-mises stress value is taken as the output and the output parameters are calculated. The output parameters include the maximum and minimum stresses.
#  ![Screenshot (19).png](data:image/png;base64,...)![Screenshot (18).png](data:image/png;base64,...)![Screenshot (17).png](data:image/png;base64,...)![Screenshot (16).png](data:image/png;base64,...)![Screenshot (15).png](data:image/png;base64,...)![Screenshot (14).png](data:image/png;base64,...)![Screenshot (13).png](data:image/png;base64,...)![Screenshot (11).png](data:image/png;base64,...)![Screenshot (12).png](data:image/png;base64,...)![Screenshot (4).png](data:image/png;base64,...)![Screenshot (2).png](data:image/png;base64,...)![Screenshot (3).png](data:image/png;base64,...)![Screenshot (1).png](data:image/png;base64,...)
# Initial Structure
#
#
# Von-mises Stress graph
# Now a modal simulation is done in this case the geometry remains the same so we use the same data from the static structural simulation and the body is meshed in tetrahedron structure just like the previous simulation but in this case we only consider the frequency of the disk but not the break pads so we suppress the break pad parts and then in the analysis settings we take the no of modes to find to be 10 and solve for the first deformation mode.
#
# Modal simulation of the geometry
#
#
# Now go for the transient thermal simulation and since the geometry is same we again choose the same geometric structure from the static structural simulation and we mesh the body in this case we are considering on the heat of the disk not the pads so we suppress the pads and set the initial temperature in the transient thermal as 35 degrees celsius and we need to choose the analysis settings and choose the number of steps to be 5 and convection takes place between the disk and the surroundings and we take the coefficient to be 5W/m^2.C and ambient temperature to 35 degrees. The transfer of heat flux takes place between the disk and pads and now choose the disk face where it touches the pads and set the magnitude and this should be done in both directions now solve for the temperature variations of the disk from which we can obtain the maximum and minimum temperatures.
#
# Transient thermal Simulation
#
#
# And now check the initial values of the rotor thickness, rotor outer diameter and the inner diameter. Now go to the response surface from the design exploration and in the design of experiments choose the Latin Hypercube sampling and choose the number of samples to be 10 and go into the rotor values and choose the limits for each of the values and it previews the results with different configurations and the output parameters are calculated and the results are obtained now go for the response surfaces and generate the verification points and run the simulation and we get the response graphs, local sensitivity, local sensitivity curves and spider graphs and from the optimization tab get the results and we can find the optimal structure from the results.
